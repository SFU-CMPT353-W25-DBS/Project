# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
distances = pd.read_csv("../DataAcquisition/shortest_distances.csv")

# %%
plt.boxplot(distances['distance_km']) 
plt.title('Basic Boxplot') 
plt.show()
